# %%
import pandas as pd
songs100 = pd.read_csv('http://www.zernach.com/wp-content/uploads/2020/02/songs100.csv')
songs100
# Out:
#     Unnamed: 0  ...                                    album_cover_url
# 0            0  ...  https://i.scdn.co/image/ab67616d00001e022732f5...
# 1            1  ...  https://i.scdn.co/image/ab67616d00001e022a90f8...
# 2            2  ...  https://i.scdn.co/image/ab67616d00001e027e4890...
# 3            3  ...  https://i.scdn.co/image/ab67616d00001e02bd7b27...
# 4            4  ...  https://i.scdn.co/image/ab67616d00001e02ee8d58...
# ..         ...  ...                                                ...
# 95          95  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 96          96  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 97          97  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 98          98  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 99          99  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
#
# [100 rows x 20 columns]

# %%
target = 'track_index_num'
features = songs100.drop(columns=[target, 'artist_name', 'track_name', 'track_id', 'album_cover_url']).columns

#train, test = train_test_split(songs, train_size=0.01, test_size=0.99, random_state=42)

#x_train = songs[features] 
x_train_100 = songs100[features]
y_train = songs100[target]
y_train_100 = songs100[target]
#x_test = test[features]
#y_test = test[target]

#encoder = OrdinalEncoder()
#encoder.fit(x_train, y_train)
#x_train_encoded = encoder.transform(x_train)
#x_test_encoded = encoder.transform(x_test)

# %%
train_100 = songs100.drop(columns=[target, 'artist_name', 'track_name', 'track_id', 'album_cover_url'])

# %%
x_train_100
# Out:
#     Unnamed: 0  acousticness  danceability  ...  time_signature  valence  popularity
# 0            0      0.005820         0.743  ...               4   0.1180          15
# 1            1      0.024400         0.846  ...               4   0.3710           0
# 2            2      0.025000         0.603  ...               4   0.3820          56
# 3            3      0.029400         0.800  ...               4   0.6410           0
# 4            4      0.000035         0.783  ...               4   0.9280           0
# ..         ...           ...           ...  ...             ...      ...         ...
# 95          95      0.019800         0.460  ...               4   0.7060          16
# 96          96      0.236000         0.657  ...               3   0.8670          12
# 97          97      0.007760         0.433  ...               4   0.2140          14
# 98          98      0.000977         0.499  ...               4   0.0844          17
# ...

# %%
The_songs = songs100.pivot(index='track_name', columns= by='track_name')
The_songs.head()
# Out:
#     Unnamed: 0  ...                                    album_cover_url
# 0            0  ...  https://i.scdn.co/image/ab67616d00001e022732f5...
# 1            1  ...  https://i.scdn.co/image/ab67616d00001e022a90f8...
# 2            2  ...  https://i.scdn.co/image/ab67616d00001e027e4890...
# 3            3  ...  https://i.scdn.co/image/ab67616d00001e02bd7b27...
# 4            4  ...  https://i.scdn.co/image/ab67616d00001e02ee8d58...
# ..         ...  ...                                                ...
# 95          95  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 96          96  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 97          97  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 98          98  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 99          99  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
#
# [100 rows x 20 columns]

# %%
# Out:
#     Unnamed: 0  ...                                    album_cover_url
# 0            0  ...  https://i.scdn.co/image/ab67616d00001e022732f5...
# 1            1  ...  https://i.scdn.co/image/ab67616d00001e022a90f8...
# 2            2  ...  https://i.scdn.co/image/ab67616d00001e027e4890...
# 3            3  ...  https://i.scdn.co/image/ab67616d00001e02bd7b27...
# 4            4  ...  https://i.scdn.co/image/ab67616d00001e02ee8d58...
# ..         ...  ...                                                ...
# 95          95  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 96          96  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 97          97  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 98          98  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 99          99  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
#
# [100 rows x 20 columns]

# %%
#from math import pi
 
# Set data
df = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})
 
df
# Out:
#   group  var1  var2  var3  var4  var5
# 0     A  38.0    29     8     7    28
# 1     B   1.5    10    39    31    15
# 2     C  30.0     9    23    33    32
# 3     D   4.0    34    24    14    14

# %%
x_train_100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3abc149d4555> in <module>()
# ----> 1 x_train_100
#
# NameError: name 'x_train_100' is not defined

# %%
import matplotlib.pyplot as plt

from math import pi
 
# Set data
#df = pd.DataFrame({
#'group': ['A','B','C','D'],
#'var1': [38, 1.5, 30, 4],
#'var2': [29, 10, 9, 34],
#'var3': [8, 39, 23, 24],
#'var4': [7, 31, 33, 14],
#'var5': [28, 15, 32, 14]
#})
 
 
 
# ------- PART 1: Create background
plt.style.use('fivethirtyeight')
# number of variable
categories=list(songs100)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories, size=10)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([10,20,30], ["10","20","30"], color="grey", size=5)
plt.ylim(0,40)
 
 
# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=songs100.loc[0].drop('acousticness').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Big Bank feat. 2 Chainz, Big Sean, Nicki Mina")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=songs100.loc[1].drop('acousticness').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="BAND DRUM (feat. A$AP Rocky)")
ax.fill(angles, values, 'r', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.01, 0.01))

# %%
songs100['Unnamed: 0']
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 95    95
# 96    96
# 97    97
# 98    98
# 99    99
# Name: Unnamed: 0, Length: 100, dtype: int64

# %%
#dic = rule: values
area_dict = dict(zip(songs100['track_name'], songs100['Unnamed: 0']))

#songs100.to_dict(songs100['track_name'],songs100['Unnamed: 0'])
area_dict
# Out:
# {"A Day's Routine - Interlude": 94,
#  'A State Of Trance (ASOT 874) - ASOT Live From Tommorowland 2018 Announcement': 82,
#  'A State Of Trance (ASOT 874) - Coming Up, Pt. 1': 95,
#  'A State Of Trance (ASOT 874) - Coming Up, Pt. 2': 88,
#  'A State Of Trance (ASOT 874) - Coming Up, Pt. 3': 83,
#  'A State Of Trance (ASOT 874) - Interview with ARTY, Pt. 1': 91,
#  'A State Of Trance (ASOT 874) - Interview with ARTY, Pt. 2': 96,
#  'A State Of Trance (ASOT 874) - Intro': 99,
#  'A State Of Trance (ASOT 874) - Track Recap, Pt. 1': 79,
#  'A State Of Trance (ASOT 874) - Track Recap, Pt. 2': 80,
#  'A State Of Trance (ASOT 874) - Track Recap, Pt. 3': 81,
#  'Among - Original mix': 8,
#  'Astou - Original mix': 30,
#  'Azile (ASOT 874)': 75,
#  'BAND DRUM (feat. A$AP Rocky)': 1,
#  'BLACK HEART': 58,
#  'Balenciaga': 59,
#  'Bathroom - Original mix': 32,
#  'Bday Cake': 52,
#  'Beb': 40,
#  'Bien De To': 47,
#  'Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj': 0,
# ...

# %%
def zero():
    return songs100.loc[0].drop('acousticness').values.flatten().tolist()
 
def one():
    return songs100.loc[1].drop('acousticness').values.flatten().tolist()
 
def two():
    return "two"
 
switcher = {
        0: zero,
        1: one,
        2: two
    }
 
 
def change_loc(argument):
    # Get the function from switcher dictionary
    func = switcher.get(argument, "nothing")
    # Execute the function
    return func()
 
#Input: numbers_to_strings(1)
#Output: One
 
#Input: switcher[1]=two #changing the switch case
#Input: numbers_to_strings(1)
#Output: Two

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-38a2131772b5> in <module>()
# ----> 1 input1
#
# NameError: name 'input1' is not defined

# %%
change_loc(1)
# Out:
# [1,
#  'YG',
#  '1tHDG53xJNGsItRA3vfVgs',
#  'BAND DRUM (feat. A$AP Rocky)',
#  0.846,
#  214800,
#  0.557,
#  0.0,
#  8,
#  0.28600000000000003,
#  -7.258999999999999,
#  1,
#  0.457,
#  159.009,
#  4,
#  0.371,
#  0,
#  1,
#  'https://i.scdn.co/image/ab67616d00001e022a90f81ab1f368878313bb1a']
