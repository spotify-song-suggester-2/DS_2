# %%
import pandas as pd
songs = pd.read_csv('http://www.zernach.com/wp-content/uploads/2020/02/SpotifyAudioFeaturesApril2019.csv')
track_ids = songs['track_id']
track_ids
# Out:
# 0         2RM4jf1Xa9zPgMGRDiht8O
# 1         1tHDG53xJNGsItRA3vfVgs
# 2         6Wosx2euFPMT14UXiWudMy
# 3         3J2Jpw61sO7l6Hc7qdYV91
# 4         2jbYvQCyPgX3CdmAzeVeuS
#                    ...
# 130658    0cvfSKcm9VeduwyYPrxtLx
# 130659    43MP9F7UzvfilSrw2SqZGJ
# 130660    4TWlUuFk81NGUNKwndyS5Q
# 130661    5iGBXzOoRo4sBTy8wdzMyK
# 130662    7LNtyuekYHiZ99UxkrfCQR
# Name: track_id, Length: 130663, dtype: object

# %%
top_250_songs = songs[0:250]
track_ids_100 = top_100_songs['track_id']

# %%
# !pip install spotipy

# %%
Client = '51d7172cc5df4c98bf75850b33348ba6'
secret = '96b2be0725344229b37ad704401fb478'

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os.path
from os import path

#df_str = "spotify:track:" + songs['track_id'].to_string()

img_urls = []

for num in track_250_songs:
  id_url = "spotify:track:" + num
  spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(Client, secret))
  results = spotify.track(id_url)
  #if path.exists("results['album']['images'][1]['url']"):
   # img_url = results['album']['images'][1]['url']
  #else:
   # img_url = 0

 # if path.exists('img_url') == True:
  #  img_urls.append(img_url)
  #else:     
  #  img_urls.append(img_url)
    
    
  while True:
    try:
      img_url = results['album']['images'][1]['url']
      break
    except ValueError:
      img_url = 0
      #break
  img_urls.append(img_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c1d193d8e037> in <module>()
#       8 img_urls = []
#       9
# ---> 10 for num in track_250_songs:
#      11   id_url = "spotify:track:" + num
#      12   spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(Client, secret))
#
# NameError: name 'track_250_songs' is not defined

# %%
img_url = results['album']['images'][1]['url']
img_url1= results.get('url')
print(img_url1)
# Out:
# None

# %%
for num in track_ids:
  id_url = "spotify:track:" + num
  spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(Client, secret))
  results = spotify.track(id_url)
# Out:
# retrying ...3secs
# retrying ...1secs
# retrying ...2secs
# retrying ...1secs
# retrying ...5secs
# retrying ...5secs
# retrying ...5secs
# retrying ...1secs
# retrying ...5secs
# retrying ...5secs
# retrying ...2secs
# retrying ...5secs
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     136             try:
# --> 137                 r.raise_for_status()
#     138             except BaseException:
#
# /usr/local/lib/python3.6/dist-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.spotify.com/v1/tracks/5tWxzX94yRTL6k9pzVVQy8
#
# ...

# %%
for x in results:
      print(results['album']['images'][1]['url'])
 #type(results)
# Out:
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# https://i.scdn.co/image/ab67616d00001e0298f2fc4d32a54591b7878d55
# ...

# %%
top_100_songs['album_cover_url'] = img_urls
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
top_100_songs
# Out:
#          artist_name  ...                                    album_cover_url
# 0                 YG  ...  https://i.scdn.co/image/ab67616d00001e022732f5...
# 1                 YG  ...  https://i.scdn.co/image/ab67616d00001e022a90f8...
# 2              R3HAB  ...  https://i.scdn.co/image/ab67616d00001e027e4890...
# 3         Chris Cooq  ...  https://i.scdn.co/image/ab67616d00001e02bd7b27...
# 4         Chris Cooq  ...  https://i.scdn.co/image/ab67616d00001e02ee8d58...
# ..               ...  ...                                                ...
# 95  Armin van Buuren  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 96  Armin van Buuren  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 97            Hamzeh  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 98             MaRLo  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
# 99  Armin van Buuren  ...  https://i.scdn.co/image/ab67616d00001e0298f2fc...
#
# [100 rows x 18 columns]

# %%
img_urls
# Out:
# ['https://i.scdn.co/image/ab67616d00001e022732f5e923a01e803df47266',
#  'https://i.scdn.co/image/ab67616d00001e022a90f81ab1f368878313bb1a',
#  'https://i.scdn.co/image/ab67616d00001e027e48906b2c6bdd93902e3ab6',
#  'https://i.scdn.co/image/ab67616d00001e02bd7b27cd82e71406f79cfc8b',
#  'https://i.scdn.co/image/ab67616d00001e02ee8d584b6e230f5faf0e47e2',
#  'https://i.scdn.co/image/ab67616d00001e02b91d48bed9ce12440f4ad4b3',
#  'https://i.scdn.co/image/ab67616d00001e023e8f49afdd73bc8713489ec4',
#  'https://i.scdn.co/image/ab67616d00001e023ce78380a5a235de54d74f35',
#  'https://i.scdn.co/image/ab67616d00001e02d7e94f8dab1a143742449a04',
#  'https://i.scdn.co/image/ab67616d00001e027b3452cd5795ff6e6f8593e4',
#  'https://i.scdn.co/image/ab67616d00001e02ecff0ffdcaa2b45119422d52',
#  'https://i.scdn.co/image/ab67616d00001e02f16f0611a7767332b278d5cc',
#  'https://i.scdn.co/image/ab67616d00001e028fa6aa6a2ccbe9abd8b9e7a5',
#  'https://i.scdn.co/image/ab67616d00001e020d96cd69a21515c1a115beee',
# ...

# %%
img_urls
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0, 0]

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

lz_uri = 'spotify:artist: + 36QJpDe2go2KgaRleHCDTp'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(Client, secret))
results = spotify.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Stairway to Heaven - Remaster
# audio    : https://p.scdn.co/mp3-preview/8226164717312bc411f8635580562d67e191a754?cid=51d7172cc5df4c98bf75850b33348ba6
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Immigrant Song - Remaster
# audio    : https://p.scdn.co/mp3-preview/8455599677a13017978dcd3f4b210937f0a16bcb?cid=51d7172cc5df4c98bf75850b33348ba6
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
#
# track    : Whole Lotta Love - 1990 Remaster
# audio    : https://p.scdn.co/mp3-preview/ce11b19a4d2de9976d7626df0717d0073863909c?cid=51d7172cc5df4c98bf75850b33348ba6
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Black Dog - Remaster
# audio    : https://p.scdn.co/mp3-preview/9b76619fd9d563a48d38cc90ca00c3008327b52e?cid=51d7172cc5df4c98bf75850b33348ba6
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# ...
